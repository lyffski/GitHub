# %% [markdown]
# # Finanzmathematik
# ---
# # Prozent(rechnung)
# ### Defintion
# Zahlenangaben in Prozent (lat.-ital. von Hundert, Hundertstel) sollen __Größenverhältnisse veranschaulichen und vergleichbar machen__, indem die Größen zu __einem einheitlichen Grundwert ins Verhältnis__ gesetzt werden. Daher wird das Prozent auch __als Hilfsmaßeinheit für Verhältnisgrößen__ verwendet.
# ### Notation
# $\color{blue}{\text{Grundwert GW:}}$ Die Ausgangsgröße (entspricht 100 %)<br>
# $\color{green}{\text{Protzentwert PW:}}$ Der anteilige Wert, gemäß $\color{#B22222}{\text{Prozentsatz (p%)}}$ vom Grundwert abgeleitet.<br>
# $\color{#B22222}{\text{Prozentsatz p %: }}$Der Anteil von $\color{green}{\text{PW}}$ an $\color{blue}{\text{GW}}$, ausgedrückt in Prozent<br>
# Prozentfuß p: Die Zahl vor dem Prozentzeichen.<br>
#
# $$
# \color{green}{\text{PW:}} = \frac{\color{blue}{\text{GW}} * p}{100}
# $$
#
# Damit lautet die Grundformel für den Prozentsatz $\color{#B22222}{\text{Prozentsatz p % }}$ als Verhältnis aus $\color{green}{\text{Protzentwert PW}}$ und $\color{blue}{\text{Grundwert (GW)}}$:
# <br>
# $\color{#B22222}{\text{Prozentsatz p % }}= \frac{\color{green}{\text{PW}}}{\color{blue}{\text{GW}}}$
# <br>
#
# Für den Prozentfuß (p) an Stelle des $\color{#B22222}{\text{Prozentsatz (p %) }}$ nimmt die Formel folgende Form an:
# <br>
# $p = 100 * \frac{\color{green}{\text{PW}}}{\color{blue}{\text{GW}}}$
# <br>
#
# Je nach Verwendungszweck kann die Grundformel auch nach dem $\color{blue}{\text{Grundwert (GW)}}$ oder nach dem $\color{green}{\text{Protzentwert PW}}$aufgelöst werden:
# <br>
# $\color{blue}{\text{GW}} = \frac{\color{green}{\text{PW}}}{\color{#B22222}{\text{Prozentsatz p % }}}$
# <br>
#
# und nach eleminirungs Verfahren lässt sich festellen:
# <br>
# $\color{green}{\text{PW}} = \color{#B22222}{\text{Prozentsatz p % }} * \color{blue}{\text{GW}}$
# <br>
# <br>
# ### Beispiel
# Wenn $\color{green}{\text{42 kg}}$ genau $\color{#B22222}{\text{7%}}$ sind, welches Gewicht entspricht den vollen $\color{blue}{\text{100%}}$
# <br>
#
# __Gegeben:__
# - $\color{green}{\text{PW}} = \color{green}{42}$ kg als Protzentwert
# - $\color{#B22222}{\text{p % }} = \color{#B22222}{7 \% }$ als Protzentsatz
# <br>
#
# __Gesucht:__ $\color{blue}{\text{Grundwert (GW)}}$
# <br>
#
# __Rechnung:__
# $$
# \color{blue}{\text{GW}} = \frac{\color{green}{\text{PW}}}{\color{#B22222}{\text{p % }}} = \frac{\color{green}{\text{42}}}{\color{#B22222}{\text{7 %}}}kg = \frac{\color{green}{\text{42}}}{\color{#B22222}{\frac{7}{100}}}kg  = \frac{\color{green}{\text{42}}*100}{7}kg = \color{blue}{\text{600}} kg
# $$
# <br>
# __Vorgang:__<br>
# Die Lösung ergibt sich mit der __nach__ $\color{blue}{\text{GW}}$ __aufgelösten__ Prozentsatz-Grundformel (sehe: Rechnung)

# %%
def prozent(ls):
    '''Input: (PW,GW,p)'''
    ls = ls.split(";")
    
    if ls[0] == "PW": #falls gesucht PW
        return round(float(ls[1]) * (float(ls[2])/100), 2)
    if ls[1] == "GW": #falls gesucht GW
        return round(float(ls[0]) / (float(ls[2])/100), 2)
    if ls[2] == "p": #falls gesucht p
        return round(float(ls[0]) / float(ls[1]), 2)
    
    
# print(prozent.__doc__) # function describtion
print(prozent("42;600;p"))
# Out:
# Input: (PW,GW,p)
# 0.07

# %% [markdown]
# # Zins & Zinseszins(rechung)
# ### Definition für Zins
# __Zins (lateinisch census ‚Abschätzung‘) ist__ in der Wirtschaft das Entgelt, das der Schuldner dem Gläubiger __als Gegenleistung für vorübergehend überlassenes Kapital zahlt.__
# #### Formel:
# $$
# \color{peachpuff}{\text{Zinsen (Z)}} = \frac{\color{blue}{\text{Kapital (K)}} * \color{green}{\text{Zinssatz (p)}} * \color{#FFD700}{\text{Tage (t)}}}{100*360}
# $$
# Dementsprechend:<br>
# $\color{blue}{K} = \frac{\color{peachpuff}{\text{Z}} * 100 * 360}{\color{green}{p} * \color{#FFD700}{t}}$<br>
# $\color{green}{p} = \frac{\color{peachpuff}{\text{Z}} * 100 * 360}{\color{blue}{K} * \color{#FFD700}{t}}$<br>
# $\color{#FFD700}{t} = \frac{\color{peachpuff}{\text{Z}} * 100 * 360}{\color{blue}{K} * \color{green}{p}}$<br>
# <br>
#
# ### Definition für Zinseszins
# - __Zinseszins (englisch compound interest)__ ist im Finanzwesen __ein fälliger Zins__, der dem Kapital hinzugefügt (heißt, kapitalisiert) und künftig __zum geltenden Zinssatz zusammen mit dem Kapital verzinst wird__.<br>
# - __Zinseszinsen__ werden im Spargeschäft vergeben. Dabei wird nicht nur der bei der Bank angelegte Betrag verzinst, sondern __auch die in der Vergangenheit eingenommenen Zinsen miteinbezogen__.
#
# ### Notation
# - $\color{blue}{\text{Anfangskapital: } K_n}$ (Kapital nach $0$ (null) Jahren)<br>
# - $\color{#2888ac}{\text{Endkapital: } K_0}$ (Kapital nach $n$ Jahren)<br>
# - $\color{#FF8C00}{\text{Laufzeit: } n}$ Eingabe in __Jahren__<br>
# - $\color{#FFD700}{\text{Laufzeit: } t}$ Eingabe in __Tagen__<br>
# - $\color{green}{\text{Zinssatz: } p}$ (pro Zinsperiode)<br>
# - $\color{olive}{\text{Zinsfaktor: } q} = 1+\frac{\color{green}{p}}{100}$ (folgt aus p)<br>
#
# ##### Kaufmännisches Jahr
#     Je nach Berechnungsmethode schwankt das Jahr zwischen 360 und 366 Tagen, der Monat zwischen 28 und 30 bis 31 Tagen. Z. B. 7 % Zinssatz für die Laufzeit von 360 Tagen.
#
# ### Exponentielle Verzinsung
# Die Formel für das Kapital nach $n$ Jahren bei jährlicher Verzinsung und Zinseszinsen lautet:
# $$
# \color{blue}{K_n} = \color{#2888ac}{K_0} * \color{olive}{q}^\color{#FF8C00}{n}
# $$
#
# <br>
#
# Die Formel lässt sich __umstellen__, um bei gegebenem Endkapital das Startkapital, den Zinssatz oder die Laufzeit zu bestimmen:<br>
# $
# \color{#2888ac}{K_0} = \frac{\color{blue}{K_n}}{\color{olive}{q}^\color{#FF8C00}{n}}
# $
# <br>
# $
# \color{olive}{q} = \sqrt[\color{#FF8C00}{n}]{\frac{\color{blue}{K_n}}{\color{#2888ac}{K_0}}}
# $
# <br>
# $
# \color{#FF8C00}{n} = \log_{\color{olive}{q}} (\frac{\color{blue}{K_n}}{\color{#2888ac}{K_0}})
# $
# <br><br>
#
# #### Note: Funktionen
# <img src="pic/mathfunc.png">

# %%
import math
import re

def zins(st):
    '''
    Input: zins(K_n;K_o;p;n) # Mind the order
    Note: if you use the 1st instance make sure to have space between operators
    '''
    ls = re.split(";| = | \* |\^",st)
    if ls[0] == "K_n":
        #parsing input
        #fK_n = float(ls[0])= missing 
        K_o = float(ls[1])
        p = float(ls[2])
        n = float(ls[3])
        K_n = K_o * (1+p/100)**n
        return round(K_n,2)

    if ls[1] == "K_o":
        #parsing input
        K_n = float(ls[0])
        #K_o = float(ls[1]) = missing
        p = float(ls[2])
        n = float(ls[3])
        #calc
        K_o = K_n / (1+p/100)**n
        return round(K_o,2)

    if ls[2] == "p":
        #parsing input
        K_n = float(ls[0])
        K_o = float(ls[1])
        #p = float(ls[2]) = missing
        n = float(ls[3])
        #calc
        q = (K_n / K_o)**(1/n)
        p = (q-1) *100
        return round(p,2)

    if ls[3] == "n":
        #parsing input
        K_n = float(ls[0])
        K_o = float(ls[1])
        p = float(ls[2])
        #n = float(ls[3]) missing
        #calc
        K = K_n / K_o
        q = 1+p/100
        n = math.log(K,10) / math.log(q,10)
        return round(n,2)
    
    
# print(zins.__doc__) # function describtion
print(zins("K_n;2000;3.7;44"))
# Out:
# 9892.25

# %% [markdown]
# # Renten(rechnung)
# ## Definition
# Unter einer Rente versteht man Einzahlungen, die
# in gleichen Zeitabständen und immer in gleicher Höhe getätigt werden. <br>
# Die Einzahlungen werden als Raten (r) bezeichnet.
# <br>
# Neben der Rate r (=Betrag, der regelmäßig eingezahlt wird) unterscheidet man auf folgende Punkte:
# <br>
# ---
# #### Unterscheidungsmerkmal zwischen
# - Anfang des Zahlungsperiode (Jahr)
# - Ende des Zahlungsperiode (Jahr)
# <br>
# ---
# #### Zeitpunkt der Einzahlung
# - __vorschüssig bei Anfang__, heißt am Anfang der Zahlungsperiode (Jahres)<br>
# - __nachschüssig bei Ende__, heißt am Ende der Zahlungsperiode (Jahres)
# <br>
# ---
# #### Zeitpunkt des Gesamtwertes
# - __Barwert__, bedeutet __Gesamtwert am Anfang der Rentenzahlungen__ (z.B.: welche Schuld muss abgezahlt werden)<br>
# - __Endwert__, bedeutet __Gesamtwert am Ende der Rentenzahlungen__ (heißt: Welcher Betrag wurde angespart)
# <br>
# ---
# #### Einzahlungsperiode
# - __Ganzjährige Rente__, heißt Einzahlungen erfolgen __jährlich__<br>
# - __Unterjährige Rente__, heißt Einzahlungen erfolgen __mehrmals im Jahr__ (z.B. monatlich).
#     - Bei unterjährigen Renten muss der äquivalente Zinssatz berechnet werden. (Exkurs)
# <br><br>
#
# ### Notation
# - $\color{blue}{\text{Anfangskapital: } K_0}$ (Kapital nach $0$ (null) Jahren)<br>
# - $\color{#2888ac}{\text{Endkapital: } K_n}$ (Kapital nach $n$ Jahren)<br>
# - $\color{#FF8C00}{\text{Laufzeit: } n}$ Eingabe in __Jahren__<br>
# - $\color{#FFD700}{\text{Laufzeit: } t}$ Eingabe in __Tagen__<br>
# - $\color{green}{\text{Zinssatz: } p}$ (pro Zinsperiode)<br>
# - $\color{olive}{\text{Zinsfaktor: } q} = 1+\frac{\color{green}{p}}{100}$ (folgt aus p)<br>
# - $\color{darkred}{\text{Rente: }r}$ (Einzahlung __im gleicher Höhe und gleichen Zeitabständen__. (z.B.: auf Sparkonto))
# <br>
# <br>
# <br>
#
# $$
# \begin{matrix}
#  & & \text{nachschüssig} & \text{vorschüssig}
# \\
# \\
# \text{Endwert} & & \color{blue}{K_n} = \color{darkred}{r} * \frac{\color{olive}{q}^{\color{#FF8C00}{n}}-1}{\color{olive}{q}-1}
# &
# \color{blue}{K_n}^{´} = \color{darkred}{r} * \color{olive}{q} * \frac{\color{olive}{q}^{\color{#FF8C00}{n}}-1}{\color{olive}{q}-1}
# \\
# \\
# \text{Kapitalmehrung} & & \color{blue}{K_n} = \color{olive}{q}^{\color{#FF8C00}{n}} + \color{darkred}{r} * \frac{\color{olive}{q}^{\color{#FF8C00}{n}}-1}{\color{olive}{q}-1}
# &
# \color{blue}{K_n}^{´} = \color{#2888ac}{K_0} * \color{olive}{q}^{\color{#FF8C00}{n}} + \color{darkred}{r} * \frac{\color{olive}{q}^{\color{#FF8C00}{n}}-1}{\color{olive}{q}-1}
# \\
# \\
# \text{Kapitalminderung} & & \color{blue}{K_n} = \color{olive}{q}^{\color{#FF8C00}{n}} - \color{darkred}{r} * \frac{\color{olive}{q}^{\color{#FF8C00}{n}}-1}{\color{olive}{q}-1}
# &
# \color{blue}{K_n}^{´} = \color{#2888ac}{K_0} * \color{olive}{q}^{\color{#FF8C00}{n}} - \color{darkred}{r} * \frac{\color{olive}{q}^{\color{#FF8C00}{n}}-1}{\color{olive}{q}-1}
# \end{matrix}
# $$
# <br>
# <br>

# %%
import math

def rent(K_o, r, q, n, o1=False, o2=True):
    '''
    Input: rent(K_o; r; q; n; (o1;o2;o3))
    Option: o1(=if in advance or afterwords); o2 (=if k increase or decrease)
    '''
    q = (1+q/100)
    if o1 == True: # vorschüssig
        if o2 == True: # mehrung
            K_n = K_o * q**n + (r * q * ((q**n - 1) / (q - 1)))
        else: # minderung
            K_n = K_o * q**n - (r * q * ((q**n - 1) / (q - 1)))
        return round(K_n,2)

    elif o1 == False: # nachschüssig
        if o2 == True: # mehrung
            K_n = K_o * q**n + (r * ((q**n - 1) / (q - 1)))
        else:  # minderung
            K_n = K_o * q**n - (r * ((q**n - 1) / (q - 1)))
        return round(K_n,2)
                 
    
def find_n (k_n, k_o, r, p, o1=True, o2=True):
    '''
    Input: find_n(k_n, k_o, r, q, 
    Option: o1 (=if vorschüssiger oder nachschüssiger), o2 (=if merhrung oder minderung)
    '''
    q = 1 + (p / 100)
    if o1 == True: # vorschüssig
        if o2 == True: # mehrung
            # k_n = k_o * q^n + r * q * q^n-1 / q - 1 # init eq
            x1 = round((r * q) / (q - 1), 4)
            # k_n = k_o * q^n + x1 * (q^n-1) distributive 
            # k_n = k_o * q^n + x1 * q^n - x1
            # k_n = q^n * (k_0 + x1) - x1
            xn = round((k_n + x1) / (k_o + x1), 4)
            return round(math.log(xn, q),2) # return n

        else: # minderung
            # k_n = k_o * q^n + (-r) * q * q^n-1 / q - 1 # init eq
            x1 = round((-(r) * q) / (q - 1), 4)
            # k_n = k_o * q^n + x1 * (q^n-1) distributive 
            # k_n = k_o * q^n + x1 * q^n - x1
            # k_n = q^n * (k_0 + x1) - x1
            xn = round((k_n + x1) / (k_o + x1), 4)
            return round(math.log(xn, q), 2) # return n
            
    elif o1 == False: # nachschüssig
        if o2 == True: # Mehrung
            # k_n = k_o * q^n + r * q^n-1 / q - 1 # init eq
            x1 = round(r / (q - 1), 4)
            # k_n = k_o * q^n + x1 * (q^n-1) distributive 
            # k_n = k_o * q^n + x1 * q^n - x1
            # k_n = q^n * (k_0 + x1) - x1
            xn = round((k_n + x1) / (k_o + x1), 4)
            return round(math.log(xn, q), 2) # return n

        else: # minderung
            # k_n = k_o * q^n - r * q^n-1 / q - 1 # init eq
            x1 = round(-(r) / (q - 1), 4)
            # k_n = k_o * q^n + x1 * (q^n-1) distributive 
            # k_n = k_o * q^n + x1 * q^n - x1
            # k_n = q^n * (k_0 + x1) - x1
            xn = round((k_n + x1) / (k_o + x1), 4)
            return round(math.log(xn, q), 2) # return n
    else: pass

    
def find_r():
    pass

    
print(rent.__doc__) # function describtion
print(rent(2000,533.61,3.7,6))
print(find_n.__doc__) # function describiton
print(find_n(6000,1500,650, 3, o1 = False))
# Out:
#     Input: rent(K_o; r; q; n; (o1;o2;o3))
#     Option: o1(=if in advance or afterwords); o2 (=if k increase or decrease)
#
# 5999.99
#
#     Input: find_n(k_n, k_o, r, q,
#     Option: o1 (=if vorschüssiger oder nachschüssiger), o2 (=if merhrung oder minderung)
#
# 6.0

# %% [markdown]
# # Tilgungs(rechnung)
# ## Defintion
# Tilgungsdarlehen ist im Bankwesen der __Oberbegriff für Darlehen__, bei denen über __eine feste Laufzeit eine Tilgungsleistung vereinbart wird__. <br>
# Der Schuldendienst setzt sich zu den jeweils vereinbarten Terminen dann __aus der Tilgungsrate und den jeweils auf die Restschuld berechneten Zinsen zusammen__. $<=>$ Das Gegensatz dazu ist das endfällige Darlehen.
# <br>
# Heißt, Tilgungsdarlehen ist: __Eine regelmäßige Abzahlung bzw. Rückzahlung einer langfristigen Schuld in Form von Teilbeträgen.__<br>
# Die __Tilgungs T__ (= Tiltigunsrate die nach bestimmte zeitperiode fällig ist) __unterscheidet man__ auf folgende Punkte:
#
# ---
# ## Ratentilgung
# Bei der Ratentilgung sind die Tilgungsraten konstant, während die Zinsbelastung sinkt. Um einen Tilgungsplan zu erstellen muss daher die Tilgungsrate zuerst bestimmt werden.
#
# Ratentilgung bedeutet, dass die Tilgungsraten gleich bleiben. Nun kann ein Kredit entweder durch
#
#  - __jährlich-gleichbleibende__ Tilgungsraten abbezahlt werden oder durch
#  - __unterjährlich gleich bleibende Raten__, d.h. konkret quartalsweise, halbjährlich, monatlich gleich bleibend etc.
#  Demzufolge, die Zinsbelastung wird jeweils von der Restschuld neu berechnet und verringert sich so mit jeder Tilgung
#          - Aktuelle Datei behandeln hier ausschließlich nur die jährlich gleichbleibenden Tilgungsraten.
# <br>
#
# ### Notation
# - $\color{blue}{\text{Anfangskapital: } K_0}$ (Kapital nach $0$ Jahren, oder die __Darlehensumme__)<br>
# - $\color{#FF8C00}{\text{Laufzeit: } n}$ Eingabe in __Jahren__<br>
# - $\color{#FFD700}{\text{Laufzeit: } t}$ Eingabe in __Tagen__<br>
# - $\color{green}{\text{Zinssatz: } p}$ (pro Zinsperiode)<br>
# - $\color{olive}{\text{Zinsfaktor: } q} = 1+\frac{\color{green}{p}}{100}$ (folgt aus p)<br>
# - $\color{SteelBlue}{\text{Tilgungsrate: } T}$ = $\frac{\color{blue}{K_o}}{\color{#FF8C00}{n}}$ (folgt aus dem __Quotient__ aus $\color{blue}{K_0}$ und $\color{#FF8C00}{n}$, ist __festes Wert__)
# - $\color{DimGray}{\text{Zinsen des v-ten Jahres: } Z_{\color{sienna}{v}}}$ = $\color{SteelBlue}{T} * (\color{olive}{q} - 1) * (\color{olive}{q} - \color{sienna}{v} + 1)$ <br>
# - $\color{MediumVioletRed}{\text{Annuität des v-ten Jahres: } A_{\color{sienna}{v}}} = \color{SteelBlue}{T} * (\color{olive}{q} - 1) * (\color{olive}{q} - \color{sienna}{v} + 1) + \color{SteelBlue}{T}$
# - $\color{MediumSlateBlue}{\text{Restschulden (am Ende des v-ten Jahres): } K_{\color{sienna}{v}}} = \color{SteelBlue}{T} * (\color{#FF8C00}{n} - \color{sienna}{v})$
# <br>
#
# mit:<br>
# $\color{sienna}{v }, \color{#FF8C00}{n } \in \mathbb{ N}_{+}$
#
# ### Beispiel
# __Gesucht:__ $\color{MediumVioletRed}{\text{Annuität des v-ten (4-ten) Jahres}}$
# <img src="pic/ratentilgung.png">
#
# $$
# \color{MediumVioletRed}{A}_{\color{sienna}{v}} = \color{SteelBlue}{T} * (\color{olive}{q}-1) * (\color{#FF8C00}{n}-\color{sienna}{v}+1) + \color{SteelBlue}{T}
# $$
# $$
# \color{MediumVioletRed}{A}_{\color{sienna}{4}} = \color{SteelBlue}{20000}  * (\color{olive}{1.05} - 1) * (\color{#FF8C00}{5} - \color{sienna}{4} + 1) + \color{SteelBlue}{20000}
# $$
# <br>
# <br>
#
# ---
# ## Annuitätentilgung
# Ein Annuitätendarlehen ist __ein Kredit, der in gleichbleibenden Raten getilgt wird__.
# <br>
# Die __Annuität__ ist die vereinbarte jährliche, __immer gleichbleibende Rate für eine Kapitalschuld, die aus einem Zins- und einem Tilgungsanteil besteht__. Also __Annüität bleibt__ die gesamte Laufzeit (n) über __gleich.__<br>
# Anhand dieser Entwicklung lässt sich festellen, dass __während der Rückzahlungs die Zinsbelastung sinkt, und die Tiliugnsleistung steigt.__
# <br>
# <img src="pic/tilgraph.png">
# <br>
#
# ### Notation bei Annuität
# - $\color{blue}{\text{Anfangskapital: } K_0}$ (Kapital nach $0$ Jahren, oder die __Darlehensumme__)<br>
# - $\color{#FF8C00}{\text{Laufzeit: } n}$ Eingabe in __Jahren__<br>
# - $\color{#FFD700}{\text{Laufzeit: } t}$ Eingabe in __Tagen__<br>
# - $\color{green}{\text{Zinssatz: } p}$ (pro Zinsperiode)<br>
# - $\color{olive}{\text{Zinsfaktor: } q} = 1+\frac{\color{green}{p}}{100}$ (folgt aus p)<br>
# - $\color{SteelBlue}{\text{Tilgungsrate: } T}$ = $\frac{\color{blue}{K_o} * (\color{olive}{q} - 1)}{\color{olive}{q}^{\color{#FF8C00}{n}}-1}$ (folgt aus dem __Quotient__ aus $\color{blue}{K_0}$ und $\color{#FF8C00}{n}$, ist __festes Wert__)
# - $\color{DimGray}{\text{Zinsen des v-ten Jahres: } Z_{\color{sienna}{v}}}$ = $\frac{\color{blue}{K_0} * (\color{olive}{q} - 1) * (\color{olive}{q}^{\color{#FF8C00}{n}} - \color{olive}{q}^{\color{sienna}{v}-1})}{\color{olive}{q}^{\color{#FF8C00}{n}}-1}$ <br>
#
# - $\color{MediumVioletRed}{\text{Annuität des v-ten Jahres: } A} = \frac{\color{blue}{K_o} * \color{olive}{q}^{\color{#FF8C00}{n}} * (\color{olive}{q} - 1)}{\color{olive}{q}^{\color{#FF8C00}{n}}- 1}$
#
# - $\color{MediumSlateBlue}{\text{Restschulden (am Ende des v-ten Jahres): } K_{\color{sienna}{v}}} = \color{blue}{K_0} * \color{olive}{q}^{\color{sienna}{v}} - \frac{\color{MediumVioletRed}{A} * (\color{olive}{q}^{\color{sienna}{v}} -1 )}{\color{olive}{q} -1}$
#
# ### Beispiele
# <br>
#
# __Gesucht:__ $\color{MediumVioletRed}{\text{Annuität des v-ten (3-ten) Jahres}}$
# <img src="pic/annitil.png">
# <br>
#
# $$
# \color{MediumVioletRed}{A} = \frac{\color{blue}{K_o} * \color{olive}{q}^{\color{#FF8C00}{n}} * (\color{olive}{q} - 1)}{\color{olive}{q}^{\color{#FF8C00}{n}}- 1}
# $$
# <br>
# $$
# \color{MediumVioletRed}{A} = \frac{\color{blue}{100000} * \color{olive}{1.03}^{\color{#FF8C00}{5}} * (\color{olive}{1.03} - 1)}{\color{olive}{1.03}^{\color{#FF8C00}{5}}- 1}
# $$
#
# <br>
#
# __Gesucht:__ $\color{DimGray}{\text{Zinsen des v-ten (3-ten) Jahres}}$
# <img src="pic/annizinsen.png">
# <br>
#
# $$
# \color{DimGray}{Z_{\color{sienna}{v}}} = \frac{\color{blue}{K_0} * (\color{olive}{q} - 1) * (\color{olive}{q}^{\color{#FF8C00}{n}} - \color{olive}{q}^{\color{sienna}{v}-1})}{\color{olive}{q}^{\color{#FF8C00}{n}}-1}
# $$
# <br>
# $$
# \color{DimGray}{Z_{\color{sienna}{3}}} = \frac{\color{blue}{100000} * (\color{olive}{1.03} - 1) * (\color{olive}{1.03}^{\color{#FF8C00}{5}} - \color{olive}{1.03}^{\color{sienna}{3}-1})}{\color{olive}{1.03}^{\color{#FF8C00}{5}}-1}
# $$

# %%
class Raten:
    def __init__(self, k_o, p, n):
        self.k_o = k_o
        self.p = p 
        self.n = n 
        self.q = 1+p/100
        self.t = round(self.k_o/self.n, 2) # only in Ratentilgung
        # self.a = round(, 2)
        # self.t_1 = round((self.k_o * (self.q-1)) / (self.q**self.n -1), 2)
    
    def zinsd(self):
        pass
    
    def annui(self):
        pass
    
    def restz(self):
        pass

    
    
class Annuität:
    def __init__(self, k_o, p, n):
        self.k_o = k_o
        self.p = p 
        self.n = n 
        self.q = 1+p/100
        self.a = round(self.k_o * self.q**self.n * (self.q-1) / ( self.q ** self.n - 1), 2)
        self.t_1 = round((self.k_o * (self.q-1)) / (self.q**self.n -1), 2)
        #self.t_v = round(self.t_1 * self.q**(self.v-1) ,2)
        self.t_n = round(self.t_1 * self.q**(self.n-1) ,2)
        
    def zinsd(self):
        ls = []
        for v in range (1,self.n+1,1):
            z_v = (self.k_o * (self.q-1) * (self.q**self.n - self.q**(v-1))) / (self.q**self.n -1)
            ls.append(z_v)
        return ls

    def annui(self):
        ls = []
        for v in range (1,self.n+1,1):
            self.t_v = self.t_1 * self.q**(v-1)
            ls.append(self.t_v)
        return ls
        
    def restz(self):
        ls = []
        for v in range (1,self.n,1):
            self.k_v = self.k_o * self.q**v - (self.a * (self.q**v -1)) / (self.q-1)
            ls.append(round(self.k_v,0))
        return ls

    def show_matrix(self):
        x1 = ann.restz()
        x2 = ann.zinsd()
        x3 = ann.annui()
        print("Restschuld:")
        print(x1)
        print("\n Zins:")
        print(x2)
        print("\n Tilugung:")
        print(x3)
        

ann = Annuität(100000, 3, 5)
ann.show_matrix()
# Out:
# Restschuld:
# [81165.0, 61764.0, 41781.0, 21199.0]
#
#  Zins:
# [3000.0000000000027, 2434.936285798274, 1852.9206601704952, 1253.4445657738806, 635.984188545366]
#
#  Tilugung:
# [18835.46, 19400.5238, 19982.539513999996, 20582.01569942, 21199.476170402602]
